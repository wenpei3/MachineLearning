# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 4.4 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://spending-chastise-bullion.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://spending-chastise-bullion.ngrok-free.dev
# True

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="什麼是AI AGENT？"
)
print(response.text)
# Out:
# AI Agent (人工智慧代理人)，簡單來說，就是一個**自主的、有目標導向的軟體或硬體實體，它能夠感知其環境，做出決策，並採取行動來實現特定的目標。**
#
# 它不僅僅是一個單純的AI模型，而是一個更完整的「系統」，能夠**主動地**與環境互動。
#
# ### AI Agent 的核心構成要素：
#
# 一個AI Agent 通常包含以下關鍵組成部分：
#
# 1.  **感知 (Perception)：** 能夠從其環境中收集資訊。這可以是透過感測器（如攝像頭、麥克風、溫度計）獲取物理數據，也可以是從數位介面（如API、數據庫、網頁內容）獲取資訊。
# 2.  **推理與決策 (Reasoning & Decision-Making)：** 接收到感知到的資訊後，Agent 會運用其內建的AI模型、演算法和邏輯來分析情況，理解目標，並決定下一步的最佳行動。這可能是基於預設規則、機器學習模型，甚至是複雜的規劃演算法。
# 3.  **行動 (Action)：** 根據決策結果，Agent 會執行相應的行動來影響其環境或實現目標。這可以是物理行動（如移動機器人手臂、駕駛車輛），也可以是數位行動（如發送電子郵件、更新數據庫、顯示資訊）。
# 4.  **記憶與學習 (Memory & Learning - 可選但常見)：** 高階的AI Agent 能夠記住過去的經驗和行動結果，並從中學習以改進未來的決策和行動。這使得它們能夠適應不斷變化的環境。
# 5.  **目標 (Goals)：** 每個AI Agent 都設定有一個或多個明確的目標，所有的感知、推理和行動都是為了達成這些目標。
#
# ### AI Agent 的運作循環 (Perceive-Think-Act Loop)：
#
# 1.  **感知 (Perceive)：** Agent 接收來自環境的輸入。
# 2.  **分析與規劃 (Analyze & Plan)：** Agent 處理輸入，與其內部知識和目標進行比對，然後規劃一個行動方案。
# 3.  **執行 (Act)：** Agent 執行其規劃的行動。
# 4.  **循環 (Loop)：** 重複這個過程，不斷感知環境變化，調整行動。
#
# ### 簡單類比：
#
# 你可以把一個AI Agent 想像成一個微型「個體」或「工人」：
# *   **眼睛/耳朵：** 負責感知（Perception）
# *   **大腦：** 負責推理和決策（Reasoning & Decision-Making）
# *   **手/腳/嘴巴：** 負責行動（Action）
# *   **待辦事項清單：** 負責目標（Goals）
#
# ### AI Agent 的種類：
#
# AI Agent 可以根據其複雜程度和能力分為不同類型，例如：
#
# *   **簡單反射 Agent (Simple Reflex Agents)：** 只根據當前感知到的資訊立即做出反應，沒有記憶。
# *   **基於模型的反射 Agent (Model-based Reflex Agents)：** 內部有一個環境模型，可以推斷未被感知的環境部分，因此能更好地處理部分可觀測的環境。
# *   **基於目標的 Agent (Goal-based Agents)：** 除了環境模型外，還有一個目標信息，能規劃一系列行動來達成目標。
# *   **基於效用的 Agent (Utility-based Agents)：** 不僅有目標，還能評估不同行動路徑的「好壞」（效用），選擇能帶來最佳結果的行動。
#
# ### AI Agent 的應用範例：
#
# *   **虛擬助理：** Siri、Alexa、Google Assistant 都是典型的軟體 AI Agent，它們感知你的語音命令，理解意圖，執行如播放音樂、設定提醒、回答問題等行動。
# *   **自動駕駛汽車：** 搭載了大量感測器（感知），車載AI系統分析路況、交通規則、目的地（推理決策），然後控制方向盤、油門、剎車（行動）。
# *   **推薦系統：** 感知你的瀏覽和購買歷史，分析偏好，推薦你可能喜歡的商品或內容。
# *   **遊戲中的NPC (Non-Player Characters)：** 在遊戲世界中感知玩家行為和環境，根據預設規則或AI邏輯採取行動。
# *   **自動交易機器人：** 感知市場數據，根據預設策略或學習模型進行買賣操作。
# *   **聊天機器人 (Chatbots)：** 感知用戶的文字輸入，理解意圖，生成回應。
# *   **工業機器人：** 感知工作環境，執行組裝、焊接等物理任務。
#
# 總之，AI Agent 代表了AI從單純的數據處理工具向**能夠自主運作、與世界互動並完成任務的實體**的演變。它是實現更廣泛、更通用AI的關鍵一步。

# %%
def stateless_query(payload):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=payload
    )
    return response.text

# %%
result = stateless_query("簡介明新科技大學")
print(result)
# Out:
# 明新科技大學（Ming Hsin University of Science and Technology，簡稱明新科大）是一所位於台灣新竹縣新豐鄉的私立科技大學。以「實務致用」為教學導向，並深耕「產學合作」的特色學府。
#
# 以下是明新科技大學的簡要介紹：
#
# 1.  **創立與沿革**：
#     *   學校創立於1966年，前身為「明新工業專科學校」。
#     *   2002年，因辦學績效卓著，經教育部核准改制升格為「明新科技大學」。
#
# 2.  **地理位置優勢**：
#     *   學校地理位置優越，毗鄰新竹科學園區、湖口工業區、竹北生醫園區等高科技與工業聚落。這使其在培育產業所需人才方面具有先天優勢，並能與產業保持緊密的連結，提供學生豐富的實習與就業機會。
#
# 3.  **教學理念與特色**：
#     *   **實務致用**：學校課程設計著重實作與應用，強調將理論知識轉化為實際操作能力，培養學生的職場即戰力。
#     *   **產學合作**：積極與各行各業建立合作關係，推動企業實習、共同研發、產學專班等，讓學生在學期間就能接觸產業脈動，累積實務經驗。
#     *   **就業導向**：以高畢業生就業率為目標，提供多元的職涯輔導與媒合服務，確保學生畢業後能順利銜接職場。
#
# 4.  **學院與學制**：
#     *   目前設有工學院、管理學院、服務事業學院、設計學院等四大專業學院，提供學士、碩士等學位課程。涵蓋了工程、資訊、管理、餐旅、幼保、設計等多元領域。
#
# 5.  **發展願景**：
#     *   明新科大致力於成為一所「技職教育典範」的優質大學，透過不斷提升教學品質、深化產學合作，培養具備專業技能、創新能力和國際視野的實用型人才，為台灣的產業發展注入新血。
#
# 總體而言，明新科技大學是一所以培育具備專業技能與職場競爭力的實用型人才為目標的綜合性科技大學，在新竹地區的產業人才培育上扮演著重要的角色。

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
)

app = Flask(__name__)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)


@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
  # 取得使用者輸入的原始文字
    text = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)

        # 💡 【為什麼前面要加 AI？】
        # 這裡的 startswith('AI ') 是一個分流機制（開關）。
        # 當符合這個條件時，程式才會把訊息傳給 Gemini AI，避免任何無意義的話都去浪費 AI 的運算額度。
        if text.startswith('AI '):
            prompt = text[3:]
            reply_text = stateless_query(prompt)
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=reply_text)]
                )
            )

        # 💡 【如果前面沒有加 AI，就走這條路】
        # 當使用者傳送的訊息開頭不是 "AI "（例如只打 "你好"、"哈囉" 或者是小寫 "ai"）
        # 程式就會判定不符合 AI 模式，自動分流到這個 else 區塊。
        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=event.message.text),
                        TextMessage(text=event.message.text)]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
